# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset
student_data = pd.read_csv('student-alcohol-consumption.csv', index_col=0)

# %%
student_data
# Out:
#     school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 0       GP   F   18     GT3       A     4     4           2         0
# 1       GP   F   17     GT3       T     1     1           1         0
# 2       GP   F   15     LE3       T     1     1           1         3
# 3       GP   F   15     GT3       T     4     2           1         0
# 4       GP   F   16     GT3       T     3     3           1         0
# ..     ...  ..  ...     ...     ...   ...   ...         ...       ...
# 390     MS   M   20     LE3       A     2     2           1         2
# 391     MS   M   17     LE3       T     3     1           2         0
# 392     MS   M   21     GT3       T     1     1           1         3
# 393     MS   M   18     LE3       T     3     2           3         0
# 394     MS   M   19     LE3       T     1     1           1         0
#
#     schoolsup  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# ...

# %%
student_data.isna()
# Out:
#      school    sex    age  famsize  Pstatus   Medu   Fedu  traveltime  \
# 0     False  False  False    False    False  False  False       False
# 1     False  False  False    False    False  False  False       False
# 2     False  False  False    False    False  False  False       False
# 3     False  False  False    False    False  False  False       False
# 4     False  False  False    False    False  False  False       False
# ..      ...    ...    ...      ...      ...    ...    ...         ...
# 390   False  False  False    False    False  False  False       False
# 391   False  False  False    False    False  False  False       False
# 392   False  False  False    False    False  False  False       False
# 393   False  False  False    False    False  False  False       False
# 394   False  False  False    False    False  False  False       False
#
#      failures  schoolsup  ...  goout   Dalc   Walc  health  absences     G1  \
# ...

# %%
# highest study time
study_time = student_data.groupby("school")[["study_time"]].max()
school = student_data.sort_values(by="study_time", ascending=False)
school.head()
# Out:
#     school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures  \
# 210     GP   F   19     GT3       T     3     3           1         0
# 67      GP   F   16     GT3       T     3     1           1         0
# 293     GP   F   17     LE3       T     3     1           2         0
# 282     GP   F   18     LE3       T     1     1           2         0
# 271     GP   F   18     GT3       T     2     3           1         0
#
#     schoolsup  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 210        no  ...     3    1    2      3       10   8   8   8     Urban
# 67        yes  ...     3    1    2      5        4   7   7   6     Urban
# 293        no  ...     2    1    1      3        6  18  18  18     Rural
# 282        no  ...     2    1    1      3        1  12  12  12     Rural
# 271        no  ...     5    1    3      2        4  15  14  14     Urban
#
#      study_time
# 210   >10 hours
# 67    >10 hours
# 293   >10 hours
# 282   >10 hours
# 271   >10 hours
# ...

# %%
# a scatter plot of absences vs. final grade
sns.scatterplot(x="absences", y="G3",
                data=student_data,
                hue="location")
plt.show()

# %%
# Change the legend order in the scatter plot
sns.scatterplot(x="absences", y="G3", 
                data=student_data, 
                hue="location",
                hue_order=["Rural", "Urban"])
plt.show()

# %%
# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# %%
# a count plot of school with location subgroups
sns.countplot(x="school", data=student_data,
              hue="location",
              palette=palette_colors)
plt.show()

# %%
# use relplot() instaed of scatterplot()
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter")
plt.show()

# %%
# make subplots based on study time
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter",
            col="study_time")
plt.show()

# %%
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", 
            row="study_time")
plt.show()

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter")
plt.show()

# %%
# Adjust to add subplots based on school support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"])
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])
plt.show()
