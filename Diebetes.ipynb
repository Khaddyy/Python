# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("health care diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      29.108073  140.671875
# std       3.369578   30.438286      12.096642       8.791221   86.383060
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  121.500000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.455208                  0.471876   33.240885    0.348958
# std      6.875177                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.Insulin.unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
df['Insulin'].value_counts()
# Out:
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 73       1
# 171      1
# 255      1
# 52       1
# 112      1
# Name: Insulin, Length: 186, dtype: int64

# %%
# Descriptive statistics
print(df[['Insulin', 'Outcome']].describe())
# Out:
#           Insulin     Outcome
# count  768.000000  768.000000
# mean    79.799479    0.348958
# std    115.244002    0.476951
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%     30.500000    0.000000
# 75%    127.250000    1.000000
# max    846.000000    1.000000

# %%
# Box plot to visualize the distribution of Outcome based on Insulin values
sns.boxplot(x='Outcome', y='Insulin', data=df)
plt.title('Distribution of Outcome based on Insulin')
plt.show()

# %%
df.shape
# Out:
# (768, 9)

# %%
df.Pregnancies.unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
df.Pregnancies.nunique()
# Out:
# 17

# %%
df[df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0].count()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# Pregnancy Analysis
pregnancy_analysis = df.groupby('Pregnancies')['Outcome'].mean()

# %%
# comparing Blood Pressure by Outcome
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='BloodPressure', hue='Outcome', multiple='stack', bins=20)
plt.title('Distribution of Blood Pressure by Outcome')
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
plt.legend(title='Outcome', labels=['No Diabetes', 'Diabetes'])
plt.show()

# %%
# Create histograms for BMI based on Outcome
sns.histplot(data=df, x='BMI', hue='Outcome', bins=30, multiple='stack')
plt.title('Distribution of BMI based on Outcome')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
# Histogram representation for Age based on Outcome
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Outcome', bins=20, multiple='stack')
plt.title('Distribution of Age based on Outcome')
plt.show()

# %%
# Correlation Heatmap
correlation_analysis = df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_analysis, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
most_Pregnancies = df['Pregnancies'].value_counts().head(5)
print("Pregnancies with the most occurrences:", most_Pregnancies)
# Out:
# Pregnancies with the most occurrences: 1    135
# 0    111
# 2    103
# 3     75
# 4     68
# Name: Pregnancies, dtype: int64

# %%
# Find the pregnancy column with the highest correlation with the outcome
max_corr_pregnancy = df.corr()['Outcome'].abs().sort_values(ascending=False).index[1]

# %%
# Calculate the number of pregnancies with the highest correlation
max_corr_pregnancy_count = df[df[max_corr_pregnancy] == df[max_corr_pregnancy].max()]['Pregnancies'].values[0]

# %%
# Identify the pregnancy with the most risk of diabetes
max_risk_pregnancy = df[df['Outcome'] == 1]['Pregnancies'].value_counts().idxmax()

# %%
print(f"Pregnancy with the highest correlation with outcome: {max_corr_pregnancy}")
print(f"Number of pregnancies with the highest correlation: {max_corr_pregnancy_count}")
# Out:
# Pregnancy with the highest correlation with outcome: Glucose
# Number of pregnancies with the highest correlation: 1

# %%
# Identify rows where pregnancy is 0 and outcome is 1 (diabetic)
pregnancy_0_diabetic = df[(df['Pregnancies'] == 0) & (df['Outcome'] == 1)]

# %%
# Identify rows where pregnancy is 1 and outcome is 1 (diabetic)
pregnancy_1_diabetic = df[(df['Pregnancies'] == 1) & (df['Outcome'] == 1)]

# %%
# Plot count of outcomes
sns.countplot(x='Outcome', data=df)

# Add labels and title
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.title('Distribution of Outcomes')

# Show the plot
plt.show()

# %%
# Count the total number of diabetic patients
total_diabetic_patients = df['Outcome'].sum()

print(f'Total number of diabetic patients: {total_diabetic_patients}')
# Out:
# Total number of diabetic patients: 268

# %%
# Filter the DataFrame to include only diabetic patients
diabetic_df = df[df['Outcome'] == 1]

# Plot the age distribution for diabetic patients
plt.hist(diabetic_df['Age'], bins=20, color='blue', edgecolor='black')
plt.title('Age Distribution of Diabetic Patients')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Filter the DataFrame to include only diabetic patients
diabetic_df = df[df['Outcome'] == 1]

# Calculate the total number of pregnant diabetic patients
total_pregnant_diabetic = diabetic_df['Pregnancies'].sum()

print(f'Total number of pregnant diabetic patients: {total_pregnant_diabetic}')
# Out:
# Total number of pregnant diabetic patients: 1304

# %%
# Calculate the average age of pregnant diabetic patients
average_age_diabetic = diabetic_df['Age'].mean()
print(f'Average age of pregnant diabetic patients: {average_age_diabetic:.2f} years')
# Out:
# Average age of pregnant diabetic patients: 37.07 years

# %%
# Calculate the average age of diabetic patients
average_age_diabetic = diabetic_df['Age'].mean()

# Print the result
print(f'Average Age of Diabetic Patients: {average_age_diabetic:.2f} years')
# Out:
# Average Age of Diabetic Patients: 37.07 years

# %%
# Plot a histogram of BMI for pregnant diabetic patients
import matplotlib.pyplot as plt
plt.hist(diabetic_df['BMI'], bins=20, color='skyblue', edgecolor='black')
plt.title('BMI Distribution of Pregnant Diabetic Patients')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation analysis for pregnant diabetic patients
correlation_diabetic = diabetic_df[['Glucose', 'BloodPressure', 'BMI', 'Age']].corr()
print('Correlation Matrix for Pregnant Diabetic Patients:')
print(correlation_diabetic)
# Out:
# Correlation Matrix for Pregnant Diabetic Patients:
#                 Glucose  BloodPressure       BMI       Age
# Glucose        1.000000       0.068699  0.050418  0.098565
# BloodPressure  0.068699       1.000000  0.133951  0.262684
# BMI            0.050418       0.133951  1.000000 -0.188012
# Age            0.098565       0.262684 -0.188012  1.000000

# %%
df["Pregnancies"].value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
df.Pregnancies.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 768 entries, 0 to 767
# Series name: Pregnancies
# Non-Null Count  Dtype
# --------------  -----
# 768 non-null    int64
# dtypes: int64(1)
# memory usage: 6.1 KB

# %%
# Plot histogram for 'Pregnancies'
sns.histplot(df['Pregnancies'], bins=20)
plt.title('Distribution of Pregnancies')
plt.show()

# %%
# Plot histogram for 'Glucose'
sns.histplot(df['Glucose'], bins=20, color='orange')
plt.title('Distribution of Glucose')
plt.show()

# %%
df[df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0].count()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# Create a boxplot to compare average blood pressure for diabetic and non-diabetic patients
plt.figure(figsize=(8, 6))
sns.boxplot(x='Outcome', y='BloodPressure', data=df, palette='pastel')
plt.title('Comparison of Blood Pressure between Diabetic and Non-Diabetic Patients')
plt.xlabel('Diabetic Status (0: Non-Diabetic, 1: Diabetic)')
plt.ylabel('Blood Pressure')
plt.show()

# %%
# Create a histogram to explore the distribution of blood pressure
plt.figure(figsize=(8, 6))
plt.hist(df['BloodPressure'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Blood Pressure')
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
plt.show()

# %%
# Determine the distribution of BMI
print("Overall BMI Distribution:")
print(df['BMI'].describe())
# Out:
# Overall BMI Distribution:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
# Compare the average BMI between diabetic and non-diabetic patients
average_bmi_diabetic = df[df['Outcome'] == 1]['BMI'].mean()
average_bmi_non_diabetic = df[df['Outcome'] == 0]['BMI'].mean()

print("nAverage BMI for Diabetic Patients:", average_bmi_diabetic)
print("Average BMI for Non-Diabetic Patients:", average_bmi_non_diabetic)
# Out:
# nAverage BMI for Diabetic Patients: 35.14253731343284
# Average BMI for Non-Diabetic Patients: 30.3042

# %%
df_rounded = df.round()

# %%
print("nAverage BMI for Diabetic Patients:", average_bmi_diabetic)
print("Average BMI for Non-Diabetic Patients:", average_bmi_non_diabetic)
# Out:
# nAverage BMI for Diabetic Patients: 35.14253731343284
# Average BMI for Non-Diabetic Patients: 30.3042

# %%
# Set the style for the plot
plt.style.use('ggplot')

# Create a histogram to explore the distribution of blood pressure
plt.figure(figsize=(8, 6))
plt.hist(df['BloodPressure'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Blood Pressure')
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
plt.show()

# %%
To calculate the distribution of insulin levels and compare the average insulin levels between diabetic and non-diabetic patients

# %%
# analyse the distribution of insulin levels
insulin_distribution = df['Insulin'].describe()

# %%
# Compare the average insulin levels between diabetic and non-diabetic patients
average_insulin_diabetic = df[df['Outcome'] == 1]['Insulin'].mean()
average_insulin_non_diabetic = df[df['Outcome'] == 0]['Insulin'].mean()

# %%
print("Distribution of Insulin Levels:")
print(insulin_distribution)

print("nAverage Insulin Levels for Diabetic Patients:", average_insulin_diabetic)
print("Average Insulin Levels for Non-Diabetic Patients:", average_insulin_non_diabetic)
# Out:
# Distribution of Insulin Levels:
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64
# nAverage Insulin Levels for Diabetic Patients: 100.33582089552239
# Average Insulin Levels for Non-Diabetic Patients: 68.792

# %%
# Explore the distribution of insulin levels
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.hist(df['Insulin'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Insulin Levels')
plt.xlabel('Insulin Levels')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Filter only pregnant patients
pregnant_df = df[df['Pregnancies'] > 0]

# Calculate average glucose levels for pregnant patients
average_glucose_pregnant = pregnant_df['Glucose'].mean()

# Print the result
print(f"Average Glucose Levels for Pregnant Patients: {average_glucose_pregnant:.2f}")
# Out:
# Average Glucose Levels for Pregnant Patients: 120.54

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Outcome', y='Insulin', data=df, palette='pastel')
plt.title('Comparison of Average Insulin Levels (Diabetic vs. Non-Diabetic)')
plt.xlabel('Outcome (0: Non-Diabetic, 1: Diabetic)')
plt.ylabel('Average Insulin Levels')
plt.show()

# %%
# Calculate average insulin levels for diabetic and non-diabetic patients
average_insulin_diabetic = df[df['Outcome'] == 1]['Insulin'].mean()
average_insulin_non_diabetic = df[df['Outcome'] == 0]['Insulin'].mean()

# Create a pie chart
labels = ['Diabetic', 'Non-Diabetic']
average_insulin_levels = [average_insulin_diabetic, average_insulin_non_diabetic]
plt.pie(average_insulin_levels, labels=labels, autopct='%1.1f%%')
plt.title('Average Insulin Levels Comparison (Diabetic vs. Non-Diabetic)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Pregnancies', y='Age', hue='Outcome', data=df, alpha=0.5)
plt.title('Scatter Plot of Pregnancy vs. Age')
plt.show()

# %%
# Scatter plot with BMI and Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='BMI', y='Age', hue='Outcome', data=df)
plt.title('Scatter Plot of BMI and Age with Outcome')
plt.xlabel('BMI')
plt.ylabel('Age')
plt.show()

# %%
#glucose and bmi
sns.scatterplot(x='Glucose', y='BMI', hue='Outcome', data=df)
plt.title('Relationship between Glucose and BMI')
plt.show()

# %%
#blood pressure and age
sns.scatterplot(x='BloodPressure', y='Age', hue='Outcome', data=df)
plt.title('Relationship between Blood Pressure and Age')
plt.show()

# %%
#Skin Thickness and Diabetes Pedigree Function relationship
sns.scatterplot(x='SkinThickness', y='DiabetesPedigreeFunction', hue='Outcome', data=df)
plt.title('Relationship between Skin Thickness and Diabetes Pedigree Function')
plt.show()

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# %%
# Create a scatter plot with color-coded outcome
sns.scatterplot(x='Age', y='Pregnancies', hue='Outcome', data=df)
plt.title('Distribution Pattern of Pregnancies and Age with Outcome')
plt.show()
