# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df=pd.read_excel("Mother Jones - Mass Shootings Database, 1982 - 2023.xlsx")
df
# Out:
#                                       case                location  \
# 0         New Mexico neighborhood shooting  Farmington, New Mexico
# 1               Texas outlet mall shooting            Allen, Texas
# 2                 Louisville bank shooting    Louisville, Kentucky
# 3      Nashville Christian school shooting    Nashville, Tennessee
# 4       Michigan State University shooting  East Lansing, Michigan
# ..                                     ...                     ...
# 139        Shopping centers spree killings       Palm Bay, Florida
# 140  United States Postal Service shooting        Edmond, Oklahoma
# 141         San Ysidro McDonald's massacre  San Ysidro, California
# 142              Dallas nightclub shooting           Dallas, Texas
# 143                  Welding shop shooting          Miami, Florida
#
#                     date                                            summary  \
# 0                5/15/23  Beau Wilson, 18, opened fire in a residential ...
# 1    2023-06-05 00:00:00  Mauricio Garcia, 33, wore tactical gear and us...
# 2    2023-10-04 00:00:00  Connor Sturgeon, 25, opened fire inside Old Na...
# 3                3/27/23  Audrey Hale, 28, who was a former student at t...
# 4                2/13/23  Anthony D. McRae, 43, opened fire at Berkey Ha...
# ..                   ...                                                ...
# 139            4/23/1987  Retired librarian William Cruse, 59, was paran...
# 140            8/20/1986  Postal worker Patrick Sherrill, 44, opened fir...
# 141            7/18/1984  James Oliver Huberty, 41, opened fire in a McD...
# 142            6/29/1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 143            8/20/1982  Junior high school teacher Carl Robert Brown, ...
#
#      fatalities  injured  total_victims location.1 age_of_shooter  \
# 0             3        6              9      Other             18
# 1             8        7             15      Other             33
# 2             5        8             13  workplace             25
# 3             6        6             12     School             28
# 4             3        5              8     School             43
# ..          ...      ...            ...        ...            ...
# 139           6       14             20      Other             59
# 140          15        6             21  Workplace             44
# 141          22       19             41      Other             41
# 142           6        1              7      Other             39
# 143           8        3             11      Other             51
#
#     prior_signs_mental_health_issues  ...  \
# 0                                yes  ...
# 1                                yes  ...
# 2                                yes  ...
# 3                                  -  ...
# 4                                  -  ...
# ..                               ...  ...
# 139                              Yes  ...
# 140                          Unclear  ...
# 141                              Yes  ...
# 142                              Yes  ...
# 143                              Yes  ...
#
#                                         weapon_details    race  \
# 0                                    AR-15-style rifle   White
# 1                                    AR-15-style rifle  Latino
# 2                                          AR-15 rifle   White
# 3                                                    -   White
# 4                                                    -   Black
# ..                                                 ...     ...
# 139  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...   white
# 140  .22-caliber, two .45-caliber Colt Model 1911-A...   white
# 141  9mm Browning P35 Hi-Power semiautomatic handgu...   white
# 142       9mm Smith & Wesson 459 semiautomatic handgun   white
# 143  Mossberg 500 Persuader pump-action shotgun wit...   white
#
#                                                 gender  \
# 0                                                    M
# 1                                                    M
# 2                                                    M
# 3    F ("identifies as transgender" and "Audrey Hal...
# 4                                                    M
# ..                                                 ...
# 139                                               Male
# 140                                               Male
# 141                                               Male
# 142                                               Male
# 143                                               Male
#
#                                                sources  \
# 0    https://www.cbsnews.com/news/farmington-shooti...
# 1    https://www.nytimes.com/2023/05/07/us/texas-ma...
# 2    https://apnews.com/article/downtown-louisville...
# 3    https://www.tennessean.com/story/news/crime/20...
# 4    https://www.cnn.com/us/live-news/michigan-stat...
# ..                                                 ...
# 139  http://articles.latimes.com/1987-04-25/news/mn...
# 140  http://news.google.com/newspapers?id=dm8aAAAAI...
# 141  http://www.utsandiego.com/san-ysidro-massacre/...
# 142  http://books.google.com/books?id=Hr3OBwP-lbUC&...
# 143  http://www.nytimes.com/1982/08/21/us/gunman-in...
#
#                                  mental_health_sources  \
# 0    https://www.nbcnews.com/news/us-news/beau-wils...
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 139  (Supreme Court of Florida Document) http://www...
# 140  http://newsok.com/sherrill-feared-mental-illne...
# 141  http://www.nctimes.com/news/local/article_2ba4...
# 142  http://books.google.com/books?id=Hr3OBwP-lbUC&...
# 143  http://news.google.com/newspapers?id=uuYLAAAAI...
#
#                                 sources_additional_age   latitude   longitude  \
# 0                                                    -          -           -
# 1                                                    -          -           -
# 2                                                    -          -           -
# 3                                                    -          -           -
# 4                                                    -          -           -
# ..                                                 ...        ...         ...
# 139  http://articles.latimes.com/1987-04-25/news/mn...  28.033189   -80.64297
# 140  http://news.google.com/newspapers?id=dm8aAAAAI...  35.667201   -97.42937
# 141  http://www.utsandiego.com/san-ysidro-massacre/...  32.552001 -117.043081
# 142  http://books.google.com/books?id=Hr3OBwP-lbUC&...  32.925166  -96.838676
# 143  http://www.nytimes.com/1982/08/21/us/gunman-in...  25.796491  -80.226683
#
#       type  year
# 0     mass  2023
# 1     Mass  2023
# 2     Mass  2023
# 3     Mass  2023
# 4     Mass  2023
# ..     ...   ...
# 139  Spree  1987
# 140   Mass  1986
# 141   Mass  1984
# 142   Mass  1984
# 143   Mass  1982
#
# [144 rows x 24 columns]

# %%
df.head(5)
# Out:
#                                   case                location  \
# 0     New Mexico neighborhood shooting  Farmington, New Mexico
# 1           Texas outlet mall shooting            Allen, Texas
# 2             Louisville bank shooting    Louisville, Kentucky
# 3  Nashville Christian school shooting    Nashville, Tennessee
# 4   Michigan State University shooting  East Lansing, Michigan
#
#                   date                                            summary  \
# 0              5/15/23  Beau Wilson, 18, opened fire in a residential ...
# 1  2023-06-05 00:00:00  Mauricio Garcia, 33, wore tactical gear and us...
# 2  2023-10-04 00:00:00  Connor Sturgeon, 25, opened fire inside Old Na...
# 3              3/27/23  Audrey Hale, 28, who was a former student at t...
# 4              2/13/23  Anthony D. McRae, 43, opened fire at Berkey Ha...
#
#    fatalities  injured  total_victims location.1 age_of_shooter  \
# 0           3        6              9      Other             18
# 1           8        7             15      Other             33
# 2           5        8             13  workplace             25
# 3           6        6             12     School             28
# 4           3        5              8     School             43
#
#   prior_signs_mental_health_issues  ...     weapon_details    race  \
# 0                              yes  ...  AR-15-style rifle   White
# 1                              yes  ...  AR-15-style rifle  Latino
# 2                              yes  ...        AR-15 rifle   White
# 3                                -  ...                  -   White
# 4                                -  ...                  -   Black
#
#                                               gender  \
# 0                                                  M
# 1                                                  M
# 2                                                  M
# 3  F ("identifies as transgender" and "Audrey Hal...
# 4                                                  M
#
#                                              sources  \
# 0  https://www.cbsnews.com/news/farmington-shooti...
# 1  https://www.nytimes.com/2023/05/07/us/texas-ma...
# 2  https://apnews.com/article/downtown-louisville...
# 3  https://www.tennessean.com/story/news/crime/20...
# 4  https://www.cnn.com/us/live-news/michigan-stat...
#
#                                mental_health_sources sources_additional_age  \
# 0  https://www.nbcnews.com/news/us-news/beau-wils...                      -
# 1                                                  -                      -
# 2                                                  -                      -
# 3                                                  -                      -
# 4                                                  -                      -
#
#   latitude longitude  type  year
# 0        -         -  mass  2023
# 1        -         -  Mass  2023
# 2        -         -  Mass  2023
# 3        -         -  Mass  2023
# 4        -         -  Mass  2023
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              144 non-null    object
#  1   location                          144 non-null    object
#  2   date                              144 non-null    object
#  3   summary                           144 non-null    object
#  4   fatalities                        144 non-null    int64
#  5   injured                           144 non-null    int64
#  6   total_victims                     144 non-null    int64
#  7   location.1                        144 non-null    object
#  8   age_of_shooter                    144 non-null    object
#  9   prior_signs_mental_health_issues  144 non-null    object
#  10  mental_health_details             144 non-null    object
#  11  weapons_obtained_legally          144 non-null    object
#  12  where_obtained                    144 non-null    object
#  13  weapon_type                       144 non-null    object
#  14  weapon_details                    143 non-null    object
#  15  race                              144 non-null    object
#  16  gender                            144 non-null    object
#  17  sources                           144 non-null    object
#  18  mental_health_sources             144 non-null    object
#  19  sources_additional_age            144 non-null    object
#  20  latitude                          144 non-null    object
#  21  longitude                         144 non-null    object
#  22  type                              144 non-null    object
#  23  year                              144 non-null    int64
# dtypes: int64(4), object(20)
# memory usage: 27.1+ KB

# %%
df.describe()
# Out:
#        fatalities     injured  total_victims         year
# count  144.000000  144.000000     144.000000   144.000000
# mean     7.756944   11.152778      18.909722  2010.645833
# std      7.398967   46.086619      51.203954    10.834721
# min      3.000000    0.000000       3.000000  1982.000000
# 25%      4.000000    1.000000       6.000000  2005.000000
# 50%      6.000000    3.000000      10.000000  2015.000000
# 75%      8.000000   10.000000      17.000000  2019.000000
# max     58.000000  546.000000     604.000000  2023.000000

# %%
df.isnull().sum()
# Out:
# case                                0
# location                            0
# date                                0
# summary                             0
# fatalities                          0
# injured                             0
# total_victims                       0
# location.1                          0
# age_of_shooter                      0
# prior_signs_mental_health_issues    0
# mental_health_details               0
# weapons_obtained_legally            0
# where_obtained                      0
# weapon_type                         0
# weapon_details                      1
# race                                0
# gender                              0
# sources                             0
# mental_health_sources               0
# sources_additional_age              0
# latitude                            0
# longitude                           0
# type                                0
# year                                0
# dtype: int64

# %%
df.replace('-', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# case                                 0
# location                             0
# date                                 0
# summary                              0
# fatalities                           0
# injured                              0
# total_victims                        0
# location.1                           0
# age_of_shooter                       2
# prior_signs_mental_health_issues    28
# mental_health_details               44
# weapons_obtained_legally            16
# where_obtained                      48
# weapon_type                          0
# weapon_details                      26
# race                                12
# gender                               0
# sources                              0
# mental_health_sources               57
# sources_additional_age              44
# latitude                            18
# longitude                           18
# type                                 0
# year                                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'sources', 'mental_health_sources',
#        'sources_additional_age', 'latitude', 'longitude', 'type', 'year'],
#       dtype='object')

# %%
df.shape
# Out:
# (144, 24)

# %%
df.case.unique()
# Out:
# array(['New Mexico neighborhood shooting', 'Texas outlet mall shooting',
#        'Louisville bank shooting', 'Nashville Christian school shooting',
#        'Michigan State University shooting',
#        'Half Moon Bay spree shooting', 'LA dance studio mass shooting',
#        'Virginia Walmart shooting', 'LGBTQ club shooting',
#        'University of Virginia shooting', 'Raleigh spree shooting',
#        'Greenwood Park Mall shooting',
#        'Highland Park July 4 parade shooting',
#        'Church potluck dinner shooting', 'Concrete company shooting',
#        'Tulsa medical center shooting', 'Robb Elementary School massacre',
#        'Buffalo supermarket massacre',
#        'Sacramento County church shooting', 'Oxford High School shooting',
#        'San Jose VTA shooting', 'FedEx warehouse shooting',
#        'Orange office complex shooting', 'Boulder supermarket shooting',
#        'Atlanta massage parlor shootings',
#        'Springfield convenience store shooting', 'Molson Coors shooting',
#        'Jersey City kosher market shooting',
#        'Pensacola Naval base shooting', 'Odessa-Midland shooting spree',
#        'Dayton entertainment district shooting',
#        'El Paso Walmart mass shooting', 'Gilroy garlic festival shooting',
#        'Virginia Beach municipal building shooting',
#        'Harry Pratt Co. warehouse shooting',
#        'Pennsylvania hotel bar shooting', 'SunTrust bank shooting',
#        'Mercy Hospital shooting', 'Thousand Oaks nightclub shooting',
#        'Tree of Life synagogue shooting', 'Rite Aid warehouse shooting',
#        'T&T Trucking shooting', 'Fifth Third Center shooting',
#        'Capital Gazette shooting', 'Santa Fe High School shooting',
#        'Waffle House shooting', 'Yountville veterans home shooting',
#        'Marjory Stoneman Douglas High School shooting',
#        'Pennsylvania carwash shooting', 'Rancho Tehama shooting spree',
#        'Texas First Baptist Church massacre',
#        'Walmart shooting in suburban Denver',
#        'Edgewood businees park shooting', 'Las Vegas Strip massacre',
#        'San Francisco UPS shooting', 'Pennsylvania supermarket shooting',
#        'Florida awning manufacturer shooting',
#        'Rural Ohio nursing home shooting', 'Fresno downtown shooting',
#        'Fort Lauderdale airport shooting', 'Cascade Mall shooting',
#        'Baton Rouge police shooting', 'Dallas police shooting',
#        'Orlando nightclub massacre', 'Excel Industries mass shooting',
#        'Kalamazoo shooting spree', 'San Bernardino mass shooting',
#        'Planned Parenthood clinic', 'Colorado Springs shooting rampage',
#        'Umpqua Community College shooting',
#        'Chattanooga military recruitment center',
#        'Charleston Church Shooting', 'Trestle Trail bridge shooting',
#        'Marysville-Pilchuck High School shooting',
#        'Isla Vista mass murder', 'Fort Hood shooting 2',
#        'Alturas tribal shooting', 'Washington Navy Yard shooting',
#        'Hialeah apartment shooting', 'Santa Monica rampage',
#        'Pinewood Village Apartment shooting', 'Mohawk Valley shootings',
#        'Sandy Hook Elementary massacre',
#        'Accent Signage Systems shooting', 'Sikh temple shooting',
#        'Aurora theater shooting', 'Seattle cafe shooting',
#        'Oikos University killings', 'Su Jung Health Sauna shooting',
#        'Seal Beach shooting', 'IHOP shooting', 'Tucson shooting',
#        'Hartford Beer Distributor shooting',
#        'Coffee shop police killings', 'Fort Hood massacre',
#        'Binghamton shootings', 'Carthage nursing home shooting',
#        'Atlantis Plastics shooting',
#        'Northern Illinois University shooting',
#        'Kirkwood City Council shooting', 'Westroads Mall shooting',
#        'Crandon shooting', 'Virginia Tech massacre',
#        'Trolley Square shooting', 'Amish school shooting',
#        'Capitol Hill massacre', 'Goleta postal shootings',
#        'Red Lake massacre', 'Living Church of God shooting',
#        'Damageplan show shooting', 'Lockheed Martin shooting',
#        'Navistar shooting', 'Wakefield massacre', 'Hotel shooting',
#        'Xerox killings', 'Wedgwood Baptist Church shooting',
#        'Atlanta day trading spree killings',
#        'Columbine High School massacre', 'Thurston High School shooting',
#        'Westside Middle School killings', 'Connecticut Lottery shooting',
#        'Caltrans maintenance yard shooting',
#        'R.E. Phelon Company shooting', 'Fort Lauderdale revenge shooting',
#        'Walter Rossler Company massacre', 'Air Force base shooting',
#        "Chuck E. Cheese's killings", 'Long Island Rail Road massacre',
#        "Luigi's shooting", '101 California Street shootings',
#        'Watkins Glen killings', 'Lindhurst High School shooting',
#        'Royal Oak postal shootings', 'University of Iowa shooting',
#        "Luby's massacre", 'GMAC massacre', 'Standard Gravure shooting',
#        'Stockton schoolyard shooting', 'ESL shooting',
#        'Shopping centers spree killings',
#        'United States Postal Service shooting',
#        "San Ysidro McDonald's massacre", 'Dallas nightclub shooting',
#        'Welding shop shooting'], dtype=object)

# %%
df.case = df.case.str.strip().str.capitalize()

# %%
df.location.unique()
df.location = df.location.str.strip().str.capitalize()

# %%
df.race.unique()
# Out:
# array(['White', 'Latino', 'Black', 'Asian', nan, 'Other',
#        'Native American', 'white', 'black', 'unclear'], dtype=object)

# %%
df.race = df.race.str.strip()

# %%
df.replace('-', np.nan, inplace=True)

# %%
df.loc[df.injured.isnull()]
# Out:
# Empty DataFrame
# Columns: [case, location, date, summary, fatalities, injured, total_victims, location.1, age_of_shooter, prior_signs_mental_health_issues, mental_health_details, weapons_obtained_legally, where_obtained, weapon_type, weapon_details, race, gender, sources, mental_health_sources, sources_additional_age, latitude, longitude, type, year]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.loc[df.fatalities.isnull()]
# Out:
# Empty DataFrame
# Columns: [case, location, date, summary, fatalities, injured, total_victims, location.1, age_of_shooter, prior_signs_mental_health_issues, mental_health_details, weapons_obtained_legally, where_obtained, weapon_type, weapon_details, race, gender, sources, mental_health_sources, sources_additional_age, latitude, longitude, type, year]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.loc[df.total_victims.isnull()]
# Out:
# Empty DataFrame
# Columns: [case, location, date, summary, fatalities, injured, total_victims, location.1, age_of_shooter, prior_signs_mental_health_issues, mental_health_details, weapons_obtained_legally, where_obtained, weapon_type, weapon_details, race, gender, sources, mental_health_sources, sources_additional_age, latitude, longitude, type, year]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Calculate the total sum of fatalities over the years
total_fatalities = df['fatalities'].sum()

print("Total Fatalities:", total_fatalities)
# Out:
# Total Fatalities: 1117

# %%
total_injured = df['injured'].sum()

print("Total Injured:", total_injured)
# Out:
# Total Injured: 1606

# %%
Total_victims = df['total_victims'].sum()

print("Total Victims:", Total_victims)
# Out:
# Total Victims: 2723

# %%
df.head(2)
# Out:
#                                case                location  \
# 0  New mexico neighborhood shooting  Farmington, new mexico
# 1        Texas outlet mall shooting            Allen, texas
#
#                   date                                            summary  \
# 0              5/15/23  Beau Wilson, 18, opened fire in a residential ...
# 1  2023-06-05 00:00:00  Mauricio Garcia, 33, wore tactical gear and us...
#
#    fatalities  injured  total_victims location.1  age_of_shooter  \
# 0           3        6              9      Other            18.0
# 1           8        7             15      Other            33.0
#
#   prior_signs_mental_health_issues  ...     weapon_details    race gender  \
# 0                              yes  ...  AR-15-style rifle   White      M
# 1                              yes  ...  AR-15-style rifle  Latino      M
#
#                                              sources  \
# 0  https://www.cbsnews.com/news/farmington-shooti...
# 1  https://www.nytimes.com/2023/05/07/us/texas-ma...
#
#                                mental_health_sources sources_additional_age  \
# 0  https://www.nbcnews.com/news/us-news/beau-wils...                    NaN
# 1                                                NaN                    NaN
#
#   latitude longitude  type  year
# 0      NaN       NaN  mass  2023
# 1      NaN       NaN  Mass  2023
#
# [2 rows x 24 columns]

# %%
df.drop('weapon_type', axis=1, inplace=True)

# %%
df.drop('where_obtained', axis=1, inplace=True)

# %%
df.drop('weapons_obtained_legally', axis=1, inplace=True)

# %%
df.drop('mental_health_details', axis=1, inplace=True)

# %%
df.drop('sources_additional_age', axis=1, inplace=True)

# %%
df.drop('sources', axis=1, inplace=True)

# %%
df.drop('longitude', axis=1, inplace=True)

# %%
df.drop('latitude', axis=1, inplace=True)

# %%
df.drop('weapon_details', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#                                case                location     date  \
# 0  New mexico neighborhood shooting  Farmington, new mexico  5/15/23
#
#                                              summary  fatalities  injured  \
# 0  Beau Wilson, 18, opened fire in a residential ...           3        6
#
#    total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 0              9      Other            18.0                              yes
#
#     race gender  type  year
# 0  White      M  mass  2023

# %%
#To show the rate of fatalities over the years
fatalities_per_year = df.groupby("year")["fatalities"].sum()
plt.figure(figsize=(20, 6))
sns.barplot(x=fatalities_per_year.index, y=fatalities_per_year.values)
plt.xlabel("fatalities", fontsize=20)
plt.ylabel("Count", fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %%
#To show the rate of injuries over the years
injuries_per_year = df.groupby("year")["injured"].sum()
plt.figure(figsize=(20, 6))
sns.barplot(x=injuries_per_year.index, y=injuries_per_year.values)
plt.xlabel("Year", fontsize=20)  
plt.ylabel("Count", fontsize=20)
plt.show()

# %%
#check the total no of injuries in 2020
injuries_2020 = df[df["year"] == 2020]
total_injuries_2020 = injuries_2020["injured"].sum()
print("Total Injuries in 2020:", total_injuries_2020)
# Out:
# Total Injuries in 2020: 0

# %%
#splitting Date column into month, day and year
df[["Month","Day","Year"]] = df["date"].str.split("/",expand=True)

# %%
deadly_month = df.groupby("Month")["Month"].count()

# %%
#Frequency of attacks in a month
plt.figure(figsize=(16, 8))
plt.bar(deadly_month.index, deadly_month.values, color="maroon", edgecolor="black")
plt.xlabel("Month", fontsize=10)
plt.ylabel("Count", fontsize=10)
plt.title("Fatalities by Month", fontsize=12)
plt.show()

# %%
#Frequency of attacks per year
deadly_year = df.groupby("year")["year"].count()

# %%
plt.figure(figsize=(16, 8))
plt.bar(deadly_year.index, deadly_year.values, color="maroon", edgecolor="black")
plt.xlabel("Year", fontsize=6)
plt.ylabel("Fatalities", fontsize=6)
plt.title("Total Fatalities by Year", fontsize=8)
plt.show()

# %%
df.groupby('year')[['total_victims', 'injured', 
                    'fatalities']].sum().sort_values(['total_victims'],
                     ascending=False).head(15).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_ec82b_row0_col0, #T_ec82b_row0_col1, #T_ec82b_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ec82b_row1_col0, #T_ec82b_row11_col2 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_ec82b_row1_col1 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_ec82b_row1_col2 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_ec82b_row2_col0 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_ec82b_row2_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_ec82b_row2_col2 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_ec82b_row3_col0 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_ec82b_row3_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_ec82b_row3_col2, #T_ec82b_row4_col2 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_ec82b_row4_col0, #T_ec82b_row5_col0 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_ec82b_row4_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_ec82b_row5_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_ec82b_row5_col2 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_ec82b_row6_col0, #T_ec82b_row6_col1, #T_ec82b_row7_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_ec82b_row6_col2 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_ec82b_row7_col1, #T_ec82b_row8_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_ec82b_row7_col2 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_ec82b_row8_col0, #T_ec82b_row9_col0, #T_ec82b_row14_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_ec82b_row8_col2, #T_ec82b_row12_col2 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_ec82b_row9_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_ec82b_row9_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_ec82b_row10_col0, #T_ec82b_row13_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_ec82b_row10_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_ec82b_row10_col2 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_ec82b_row11_col0, #T_ec82b_row12_col0 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_ec82b_row11_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_ec82b_row12_col1, #T_ec82b_row13_col0, #T_ec82b_row14_col0, #T_ec82b_row14_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ec82b_row13_col2 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# </style>
# <table id="T_ec82b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec82b_level0_col0" class="col_heading level0 col0" >total_victims</th>
#       <th id="T_ec82b_level0_col1" class="col_heading level0 col1" >injured</th>
#       <th id="T_ec82b_level0_col2" class="col_heading level0 col2" >fatalities</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec82b_level0_row0" class="row_heading level0 row0" >2017</th>
#       <td id="T_ec82b_row0_col0" class="data row0 col0" >704</td>
#       <td id="T_ec82b_row0_col1" class="data row0 col1" >587</td>
#       <td id="T_ec82b_row0_col2" class="data row0 col2" >117</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row1" class="row_heading level0 row1" >2019</th>
#       <td id="T_ec82b_row1_col0" class="data row1 col0" >185</td>
#       <td id="T_ec82b_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_ec82b_row1_col2" class="data row1 col2" >73</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_ec82b_row2_col0" class="data row2 col0" >178</td>
#       <td id="T_ec82b_row2_col1" class="data row2 col1" >104</td>
#       <td id="T_ec82b_row2_col2" class="data row2 col2" >74</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row3" class="row_heading level0 row3" >2016</th>
#       <td id="T_ec82b_row3_col0" class="data row3 col0" >154</td>
#       <td id="T_ec82b_row3_col1" class="data row3 col1" >83</td>
#       <td id="T_ec82b_row3_col2" class="data row3 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row4" class="row_heading level0 row4" >2012</th>
#       <td id="T_ec82b_row4_col0" class="data row4 col0" >151</td>
#       <td id="T_ec82b_row4_col1" class="data row4 col1" >80</td>
#       <td id="T_ec82b_row4_col2" class="data row4 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row5" class="row_heading level0 row5" >2018</th>
#       <td id="T_ec82b_row5_col0" class="data row5 col0" >150</td>
#       <td id="T_ec82b_row5_col1" class="data row5 col1" >70</td>
#       <td id="T_ec82b_row5_col2" class="data row5 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row6" class="row_heading level0 row6" >1999</th>
#       <td id="T_ec82b_row6_col0" class="data row6 col0" >89</td>
#       <td id="T_ec82b_row6_col1" class="data row6 col1" >47</td>
#       <td id="T_ec82b_row6_col2" class="data row6 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row7" class="row_heading level0 row7" >2015</th>
#       <td id="T_ec82b_row7_col0" class="data row7 col0" >89</td>
#       <td id="T_ec82b_row7_col1" class="data row7 col1" >43</td>
#       <td id="T_ec82b_row7_col2" class="data row7 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_ec82b_row8_col0" class="data row8 col0" >86</td>
#       <td id="T_ec82b_row8_col1" class="data row8 col1" >43</td>
#       <td id="T_ec82b_row8_col2" class="data row8 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row9" class="row_heading level0 row9" >2007</th>
#       <td id="T_ec82b_row9_col0" class="data row9 col0" >85</td>
#       <td id="T_ec82b_row9_col1" class="data row9 col1" >32</td>
#       <td id="T_ec82b_row9_col2" class="data row9 col2" >53</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row10" class="row_heading level0 row10" >2009</th>
#       <td id="T_ec82b_row10_col0" class="data row10 col0" >78</td>
#       <td id="T_ec82b_row10_col1" class="data row10 col1" >39</td>
#       <td id="T_ec82b_row10_col2" class="data row10 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row11" class="row_heading level0 row11" >1991</th>
#       <td id="T_ec82b_row11_col0" class="data row11 col0" >61</td>
#       <td id="T_ec82b_row11_col1" class="data row11 col1" >26</td>
#       <td id="T_ec82b_row11_col2" class="data row11 col2" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row12" class="row_heading level0 row12" >2021</th>
#       <td id="T_ec82b_row12_col0" class="data row12 col0" >59</td>
#       <td id="T_ec82b_row12_col1" class="data row12 col1" >16</td>
#       <td id="T_ec82b_row12_col2" class="data row12 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row13" class="row_heading level0 row13" >1993</th>
#       <td id="T_ec82b_row13_col0" class="data row13 col0" >57</td>
#       <td id="T_ec82b_row13_col1" class="data row13 col1" >34</td>
#       <td id="T_ec82b_row13_col2" class="data row13 col2" >23</td>
#     </tr>
#     <tr>
#       <th id="T_ec82b_level0_row14" class="row_heading level0 row14" >1989</th>
#       <td id="T_ec82b_row14_col0" class="data row14 col0" >56</td>
#       <td id="T_ec82b_row14_col1" class="data row14 col1" >41</td>
#       <td id="T_ec82b_row14_col2" class="data row14 col2" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
df["Gender"].value_counts()
# Out:
# Male                                                                                                                                                                     70
# M                                                                                                                                                                        68
# Male & Female                                                                                                                                                             2
# Female                                                                                                                                                                    2
# F ("identifies as transgender" and "Audrey Hale is a biological woman who, on a social media profile, used male pronouns,” according to Nashville Metro PD officials)     1
# F                                                                                                                                                                         1
# Name: Gender, dtype: int64

# %%
df["Gender"]= df.Gender.replace("M","Male")
df["Gender"]= df.Gender.replace("F","Female")
df["Gender"]= df.Gender.replace("M/F","Male/Female")

df["Gender"].value_counts()
# Out:
# Male                                                                                                                                                                     138
# Female                                                                                                                                                                     3
# Male & Female                                                                                                                                                              2
# F ("identifies as transgender" and "Audrey Hale is a biological woman who, on a social media profile, used male pronouns,” according to Nashville Metro PD officials)      1
# Name: Gender, dtype: int64

# %%
#pie chart representation
gender_counts = df["Gender"].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(gender_counts, labels=gender_counts.index)
plt.title("Gender Distribution")
plt.show()

# %%
gender_counts = df["Gender"].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.show()

# %%
df["race"] = df["race"].str.capitalize()
race= df["race"].value_counts()
race
# Out:
# White              76
# Black              25
# Latino             12
# Asian              10
# Other               5
# Native american     3
# Unclear             1
# Name: race, dtype: int64

# %%
sns.countplot(x='race', data=df)
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
# Scatter plot 
plt.scatter(df['total_victims'], df['Gender'])
 
# Add title to the Plot
plt.title("Scatter Plot")
 
# Set the X and Y labels
plt.xlabel('total_victims')
plt.ylabel('Gender')
 
plt.show()

# %%
# Scatter plot 
plt.scatter(df['fatalities'], df['Gender'])
 
# Add title to the Plot
plt.title("Scatter Plot")
 
# Set the X and Y labels
plt.xlabel('fatalities')
plt.ylabel('Gender')
 
plt.show()

# %%
sns.histplot(data=df, x='prior_signs_mental_health_issues', hue='Gender')
# Out:
# <Axes: xlabel='prior_signs_mental_health_issues', ylabel='Count'>

# %%
sns.countplot(x='type', data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
#countplot of race and gender distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='race', hue='Gender', data=df)
plt.xlabel('Race', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Race by Gender', fontsize=14)
plt.show()

# %%
#Scatter Plot of Total Victims Over the Years
plt.figure(figsize=(8, 6))
plt.scatter(df['year'], df['total_victims'])
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Victims', fontsize=12)
plt.title('Total Victims Over the Years')
plt.show()
